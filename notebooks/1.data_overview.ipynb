# %% [markdown]
# **Imports and Reading Data**

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/productivity_raw.csv')

# %% [markdown]
# **Data Understanding**

# %%
df.shape
# Out:
# (92, 8)

# %%
df.head()
# Out:
#        Date Day_of_Week Weather  Temperature      Mood    Music  Study_Hours  \
# 0  9/2/2025     Tuesday  Cloudy         24.4     Happy      EDM          2.3
# 1  9/3/2025   Wednesday  Cloudy         27.8  Stressed  Ambient          4.9
# 2  9/4/2025    Thursday  Cloudy         25.0       Sad   Ballad          3.1
# 3  9/5/2025      Friday  Cloudy         24.3     Happy      Pop          3.7
# 4  9/6/2025    Saturday  Cloudy         25.0     Happy      EDM          4.1
#
#   Session_Time
# 0    Afternoon
# 1    Afternoon
# 2      Evening
# 3    Afternoon
# 4      Morning

# %%
df.dtypes
# Out:
# Date             object
# Day_of_Week      object
# Weather          object
# Temperature     float64
# Mood             object
# Music            object
# Study_Hours     float64
# Session_Time     object
# dtype: object

# %%
df.describe()
# Out:
#        Temperature  Study_Hours
# count    92.000000    92.000000
# mean     23.926087     3.611957
# std       3.125115     0.796399
# min      16.600000     2.100000
# 25%      22.075000     3.075000
# 50%      24.200000     3.650000
# 75%      26.100000     4.200000
# max      29.500000     5.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of           Date Day_of_Week Weather  Temperature      Mood      Music  \
# 0     9/2/2025     Tuesday  Cloudy         24.4     Happy        EDM
# 1     9/3/2025   Wednesday  Cloudy         27.8  Stressed    Ambient
# 2     9/4/2025    Thursday  Cloudy         25.0       Sad     Ballad
# 3     9/5/2025      Friday  Cloudy         24.3     Happy        Pop
# 4     9/6/2025    Saturday  Cloudy         25.0     Happy        EDM
# ..         ...         ...     ...          ...       ...        ...
# 87  11/28/2025      Friday   Rainy         22.5     Happy       Vpop
# 88  11/29/2025    Saturday   Rainy         20.0       Sad      Indie
# 89  11/30/2025      Sunday   Rainy         21.9       Sad      Indie
# 90   12/1/2025      Monday   Rainy         17.8     Happy        Pop
# 91   12/2/2025     Tuesday   Rainy         16.6  Stressed  Classical
#
#     Study_Hours Session_Time
# 0           2.3    Afternoon
# 1           4.9    Afternoon
# ...
