# %% [markdown]
# **Univariate Analysis**

# %%
from importlib.metadata import Distribution

import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/productivity_raw.csv')

# %% [markdown]
# *Weather Distribution*

# %%
wd = df['Weather'].value_counts() \
    .plot(kind='bar', title='Weather Distribution')
wd.set_xlabel('Weather')
wd.set_ylabel('Count')
plt.show()

# %% [markdown]
# *Mood Distribution*

# %%
md = df['Mood'].value_counts() \
    .plot(kind='bar', title='Mood Distribution')
md.set_xlabel('Mood')
md.set_ylabel('Count')
plt.show()

# %% [markdown]
# *Music Distribution*

# %%
md = df['Music'].value_counts() \
    .plot(kind='bar', title='Music Distribution')
md.set_xlabel('Music')
md.set_ylabel('Count')
plt.show()

# %% [markdown]
# *Temperature Distribution*

# %%
td = df['Temperature'].plot(kind='kde', title='Temperature Distribution')
td.set_xlabel('Temperature')
td.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# *Study Hours Distribution*

# %%
sh = df['Study_Hours'].plot(kind='kde', title='Study Hours Distribution')
sh.set_xlabel('Study Hours')
sh.set_ylabel('Frequency')
plt.show()
