# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/productivity_raw.csv')

# %%
df_corr = df[['Temperature', 'Mood_Score', 'Study_Hours']].corr()
df_corr
# Out:
#              Temperature  Mood_Score  Study_Hours
# Temperature     1.000000   -0.267093     0.029633
# Mood_Score     -0.267093    1.000000    -0.008440
# Study_Hours     0.029633   -0.008440     1.000000

# %%
sns.heatmap(df_corr, annot=True, fmt='.2f')
# Out:
# <Axes: >
